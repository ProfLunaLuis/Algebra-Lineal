# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfLunaLuis/Algebra-Lineal/blob/main/Graficas_1_sol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,5,100)
y1 = (3*x-4)/2
y2= (12-5*x)/2
plt.plot(x, y1, '-r', label='y1=(3*x-4)/2')
plt.plot(x, y2, '-b', label='y2=(12-5*x)/2')
plt.title('GRafica de y_1 y y_2')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
